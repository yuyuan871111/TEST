# %% [markdown]
# # 安裝tabula-py 套件

# %% [markdown]
# ### 1. 網路上給的方法
# 在終端機上面打這行

# %% [markdown]
# pip install tabula-py

# %% [markdown]
# ### 2. 從終端機直接打這一行（可行）

# %% [markdown]
# conda install -c conda-forge tabula-py
# #### 即可安裝tabula-py 套件

# %% [markdown]
# ## 範例一

# %% [markdown]
# 記得檔案要丟在，同一個目錄底下

# %%
import tabula

# %%
# Read pdf into DataFrame
df = tabula.read_pdf( "data.pdf" )
df
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %% [markdown]
# ## 範例二（表）

# %%
df_table = tabula.read_pdf( "selection01.pdf" )
df_table
# Out:
#           Number of species in genus    141    4    3   10    1  1.1   17  \
# 0                      Gram reaction  +/v/−    +    +    +    +    −  +/−
# 1            Predominant cell shape:    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2                               Rods      +    +    +    +    +    +    +
# 3                              Cocci    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4                   Mean cell width:    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5                            <0.5 mm    NaN  NaN    +  NaN  NaN    +  NaN
# 6                         0.5–1.0 mm      +    +    +    +    +  NaN    +
# 7                     1.0 or >1.0 mm      +    +  NaN    +  NaN  NaN    +
# 8                           Motility    +/−    +    +  +/−  NaN  NaN  +/−
# 9                    Spore formation    +/−    +    +    +    +    +    +
# 10                      Spore shape:    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 11                       Ellipsoidal      +  NaN    +    +  NaN  NaN    +
# ...

# %% [markdown]
# ## 範例三（圖）沒東西

# %%
tabula?

# %%
df2_table = tabula.read_pdf( "Bergey's.Manual.[Vol.3].The.Firmicutes.pdf", pages = 607 )
df2_table
# Out:
#    d-Ribose, d-xylose, d-glucose, d-fructose, d-mannose, maltose, sucrose, +
# 0   d-cellobiose, d-trehalose, d-mannitol, α-methy...
# 1   l-Arabinose, d-galactose, lactose, d-rhamnose (+)
# 2                                        Glycerol (w)
# 3                                       d-Arabinose v
# 4   Melibiose, d-raffinose, d-melezitose, adonitol...
# 5                                      myo-Inositol −
# 6                                Gas from gluconate −
# 7         Major fatty acid composition (% of total):c
# 8                                           C 0.412:0
# 9                                           C 5.214:0
# 10                                          C 0.415:0
# 11                                         C 32.016:0
# 12                                          C 3.116:1
# 13                                      C 19.316:1 ω7
# 14                                          C 6.918:0
# 15                         C 30.218:1 ω9 (oleic acid)
# ...
