# %%
1+1
# Out:
# 2

# %%
( 4.3*12 + 4*7 + 3.7*3 + 3*3 )/25
# Out:
# 3.9879999999999995

# %%
2**3
# Out:
# 8

# %% [markdown]
# # Magical python

# %% [markdown]
# ## mathmatics

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## plot

# %%
plot ( [-2, 10, 3, 13, 5] )

# %%
randn( 10 )
# Out:
# array([ 1.08159645, -0.49507494,  0.83126866,  0.14463894, -0.10568674,
#        -0.13503294, -0.40171309, -0.04538354, -0.36524855,  0.55094677])

# %%
plot( randn( 100 ) )

# %%
plot ( [-2, 1, 2.7, 3.3, 0], [2, 3, 4, 5, 7])

# %% [markdown]
# **control m**, then **m**
# 可以切換成markdown

# %% [markdown]
# --超連結語法，**[名稱](網址）**

# %% [markdown]
# [Google](http://google.com/)

# %% [markdown]
# 物件導向

# %%
x = [1,2,3]
print(x)
# Out:
# [1, 2, 3]

# %%
print( x*3 )
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
import numpy as np
np.array( x )*3
# Out:
# array([3, 6, 9])

# %% [markdown]
# 數學符號：加💰字符號（latex）
#
# $ f(x) = x^3 +2x +3 $

# %% [markdown]
# # List

# %% [markdown]
# ## define a list

# %%
x = [ 1, 2, 3, 4, 5, 6 ]

# %%
plot( x )

# %%
y = [ 1, 2, 8, 10, 12, 14]

# %% [markdown]
# ### Python 定義 list
# List名稱 = [東西1 , 東西2, 東西3 , ...]
#
# ### List 的加法不是你想的加法
# 而是把兩個List串起來
#
# ### List 的乘法不是你想的乘法
# 而是把自己重複n次

# %%
x + y
# Out:
# [1, 2, 3, 4, 5, 6, 1, 2, 8, 10, 12, 14]

# %%
print ( "Hello, world!" )
# Out:
# Hello, world!

# %%
name = "I love you."

# %% [markdown]
# # 沒有分單雙引號

# %%
print ( "Hello, " + name + " What amazing world!" )
# Out:
# Hello, I love you. What amazing world!
